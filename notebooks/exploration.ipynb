# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Exploración rápida de GTFS edges\n",
    "Carga `data/processed/run_auto/gtfs_edges.csv.gz` y muestra estadísticas básicas."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "from pathlib import Path\n",
    "import matplotlib.pyplot as plt\n",
    "\n",
    "p = Path('data/processed/run_auto/gtfs_edges.csv.gz')\n",
    "if not p.exists():\n",
    "    raise FileNotFoundError(p)\n",
    "df = pd.read_csv(p, compression='gzip')\n",
    "df['w'] = pd.to_numeric(df['w'], errors='coerce')\n",
    "print('N edges:', len(df))\n",
    "display(df.head())\n",
    "\n",
    "plt.figure(figsize=(8,4))\n",
    "df['w'].hist(bins=50)\n",
    "plt.title('Distribución de pesos (minutos) por arista')\n",
    "plt.xlabel('weight (min)')\n",
    "plt.show()\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
